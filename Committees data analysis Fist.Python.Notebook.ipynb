# %%
import pandas

# %%
import pandas as pd
my_list = [2, 4, 6, 8]
my_series = pd.Series(my_list)
my_series.sum()
my_series.max()
my_series.min()
my_series.mean()
my_series.median()
my_series.std()
my_series.describe()
# Out:
# count    4.000000
# mean     5.000000
# std      2.581989
# min      2.000000
# 25%      3.500000
# 50%      5.000000
# 75%      6.500000
# max      8.000000
# dtype: float64

# %%
pd.read_csv("https://query.data.world/s/kbtow3x5zyrss6z4qmbo72hchtu53e")
props = pd.read_csv("https://query.data.world/s/kbtow3x5zyrss6z4qmbo72hchtu53e")
# Out:
#      bioguide chamber                  name     party  rank  thomas thomas_id  \
# 0     N000181     NaN           Devin Nunes  majority     1    1710      HLIG
# 1     C001062     NaN    K. Michael Conaway  majority     3    1805      HLIG
# 2     K000210     NaN         Peter T. King  majority     4     635      HLIG
# 3     L000554     NaN     Frank A. LoBiondo  majority     5     699      HLIG
# 4     R000583     NaN      Thomas J. Rooney  majority     7    1916      HLIG
# 5     P000602     NaN           Mike Pompeo  majority     9    2022      HLIG
# 6     R000435     NaN   Ileana Ros-Lehtinen  majority    10     985      HLIG
# 7     T000463     NaN     Michael R. Turner  majority    11    1741      HLIG
# 8     W000815     NaN      Brad R. Wenstrup  majority    12    2152      HLIG
# 9     S001192     NaN         Chris Stewart  majority    13    2168      HLIG
# 10    S001150     NaN        Adam B. Schiff  minority     1    1635      HLIG
# ...

# %%
props.head()
# Out:
#   bioguide chamber                name     party  rank  thomas thomas_id  \
# 0  N000181     NaN         Devin Nunes  majority     1    1710      HLIG
# 1  C001062     NaN  K. Michael Conaway  majority     3    1805      HLIG
# 2  K000210     NaN       Peter T. King  majority     4     635      HLIG
# 3  L000554     NaN   Frank A. LoBiondo  majority     5     699      HLIG
# 4  R000583     NaN    Thomas J. Rooney  majority     7    1916      HLIG
#
#    title
# 0  Chair
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3391 entries, 0 to 3390
# Data columns (total 8 columns):
# bioguide     3391 non-null object
# chamber      55 non-null object
# name         3391 non-null object
# party        3391 non-null object
# rank         3391 non-null int64
# thomas       3391 non-null int64
# thomas_id    3391 non-null object
# title        596 non-null object
# dtypes: int64(2), object(6)
# memory usage: 212.0+ KB

# %%
props.thomas
props.thomas.value_counts()
# Out:
# 1567    21
# 949     19
# 1507    19
# 213     18
# 968     18
# 1687    18
# 1036    17
# 452     17
# 174     17
# 735     17
# 1984    17
# 859     16
# 2175    16
# 1226    16
# 1925    16
# 2076    16
# 1823    16
# 1826    16
# 1901    16
# 1351    16
# 2138    16
# 1829    16
# 1694    16
# 1464    16
# 1695    16
# 1676    16
# 1383    15
# 1531    15
# 172     15
# 1863    15
#         ..
# 1188     3
# 2271     3
# 2060     3
# 2191     3
# 2158     3
# 1593     3
# 478      3
# 1950     3
# 854      3
# 2169     3
# 612      3
# 2165     3
# 355      2
# 683      2
# 1635     2
# 709      2
# 1037     2
# 1596     2
# 70       2
# 1809     2
# 1528     2
# 1525     2
# 1892     2
# 977      1
# 1155     1
# 229      1
# 910      1
# 1560     1
# 1729     1
# 2159     1
# Name: thomas, Length: 477, dtype: int64

# %%
props.thomas.value_counts().reset_index()
# Out:
#      index  thomas
# 0     1567      21
# 1      949      19
# 2     1507      19
# 3      213      18
# 4      968      18
# 5     1687      18
# 6     1036      17
# 7      452      17
# 8      174      17
# 9      735      17
# 10    1984      17
# 11     859      16
# 12    2175      16
# 13    1226      16
# 14    1925      16
# 15    2076      16
# 16    1823      16
# 17    1826      16
# 18    1901      16
# 19    1351      16
# 20    2138      16
# 21    1829      16
# 22    1694      16
# 23    1464      16
# 24    1695      16
# 25    1676      16
# 26    1383      15
# 27    1531      15
# 28     172      15
# 29    1863      15
# ..     ...     ...
# 447   1188       3
# 448   2271       3
# 449   2060       3
# 450   2191       3
# 451   2158       3
# 452   1593       3
# 453    478       3
# 454   1950       3
# 455    854       3
# 456   2169       3
# 457    612       3
# 458   2165       3
# 459    355       2
# 460    683       2
# 461   1635       2
# ...

# %%
props.name == 'Peter T. King'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20       True
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28       True
# 29      False
#         ...
# 3361    False
# 3362    False
# 3363    False
# 3364    False
# 3365    False
# 3366    False
# 3367    False
# 3368    False
# 3369    False
# 3370    False
# 3371    False
# 3372    False
# 3373    False
# 3374    False
# 3375    False
# 3376    False
# 3377    False
# 3378    False
# 3379    False
# 3380    False
# 3381    False
# 3382    False
# 3383    False
# 3384    False
# 3385    False
# 3386    False
# 3387    False
# 3388    False
# 3389    False
# 3390    False
# ...

# %%
prop = props[props.name == 'Peter T. King']

# %%
prop.head()
# Out:
#     bioguide chamber           name     party  rank  thomas thomas_id title
# 2    K000210     NaN  Peter T. King  majority     4     635      HLIG   NaN
# 20   K000210     NaN  Peter T. King  majority     3     635    HLIG01   NaN
# 28   K000210     NaN  Peter T. King  majority     4     635    HLIG02   NaN
# 495  K000210     NaN  Peter T. King  majority     2     635      HSBA   NaN
# 564  K000210     NaN  Peter T. King  majority     3     635    HSBA09   NaN

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 2 to 1056
# Data columns (total 8 columns):
# bioguide     9 non-null object
# chamber      0 non-null object
# name         9 non-null object
# party        9 non-null object
# rank         9 non-null int64
# thomas       9 non-null int64
# thomas_id    9 non-null object
# title        1 non-null object
# dtypes: int64(2), object(6)
# memory usage: 648.0+ bytes

# %%
props.info()
props.rank.sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3391 entries, 0 to 3390
# Data columns (total 8 columns):
# bioguide     3391 non-null object
# chamber      55 non-null object
# name         3391 non-null object
# party        3391 non-null object
# rank         3391 non-null int64
# thomas       3391 non-null int64
# thomas_id    3391 non-null object
# title        596 non-null object
# dtypes: int64(2), object(6)
# memory usage: 212.0+ KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-3b8c2a23628a> in <module>
#       1 props.info()
# ----> 2 props.rank.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
props.rank
# Out:
# <bound method NDFrame.rank of      bioguide chamber                  name     party  rank  thomas thomas_id  \
# 0     N000181     NaN           Devin Nunes  majority     1    1710      HLIG
# 1     C001062     NaN    K. Michael Conaway  majority     3    1805      HLIG
# 2     K000210     NaN         Peter T. King  majority     4     635      HLIG
# 3     L000554     NaN     Frank A. LoBiondo  majority     5     699      HLIG
# 4     R000583     NaN      Thomas J. Rooney  majority     7    1916      HLIG
# 5     P000602     NaN           Mike Pompeo  majority     9    2022      HLIG
# 6     R000435     NaN   Ileana Ros-Lehtinen  majority    10     985      HLIG
# 7     T000463     NaN     Michael R. Turner  majority    11    1741      HLIG
# 8     W000815     NaN      Brad R. Wenstrup  majority    12    2152      HLIG
# 9     S001192     NaN         Chris Stewart  majority    13    2168      HLIG
# 10    S001150     NaN        Adam B. Schiff  minority     1    1635      HLIG
# ...
